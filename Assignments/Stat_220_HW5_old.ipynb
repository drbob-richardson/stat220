# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drbob-richardson/stat220/blob/main/Assignments/Stat_220_HW5.ipynb)

# %% [markdown]
# **Problem 1** One of the earliest uses of regression was by Francis Galton who studied genetics. He used regression to predict children's heights based on the heights of their parents. There is an interesting story about it here: https://www.newyorker.com/magazine/2005/01/24/measure-for-measure-5. The following chunk loads in Galton's real data set that he used to determine the relationship between children's and parents heights.

# %%
# Run next line if in colab. Or run if need to install library
# %pip install pydataset

import pandas as pd
from pydataset import data
heights = pd.DataFrame(data("GaltonFamilies"))
heights
# Out:
# Collecting pydataset
#   Downloading pydataset-0.2.0.tar.gz (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 37.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pydataset) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pydataset) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pydataset) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pydataset) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->pydataset) (1.16.0)
# Building wheels for collected packages: pydataset
#   Building wheel for pydataset (setup.py) ... done
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939414 sha256=58d935e1641c97ab5bfc86aa8b7e729a7ea6a7f059e97401524fbb2748050110
#   Stored in directory: /root/.cache/pip/wheels/2b/83/5c/073c3755e8b7704e4677557b2055e61026c1a2342149214c13
# Successfully built pydataset
# Installing collected packages: pydataset
# Successfully installed pydataset-0.2.0
# initiated datasets repo at: /root/.pydataset/
#     family  father  mother  midparentHeight  children  childNum  gender  \
# 1      001    78.5    67.0            75.43         4         1    male
# 2      001    78.5    67.0            75.43         4         2  female
# 3      001    78.5    67.0            75.43         4         3  female
# 4      001    78.5    67.0            75.43         4         4  female
# 5      002    75.5    66.5            73.66         4         1    male
# ..     ...     ...     ...              ...       ...       ...     ...
# 930    203    62.0    66.0            66.64         3         1    male
# 931    203    62.0    66.0            66.64         3         2  female
# 932    203    62.0    66.0            66.64         3         3  female
# 933    204    62.5    63.0            65.27         2         1    male
# 934    204    62.5    63.0            65.27         2         2  female
#
#      childHeight
# 1           73.2
# 2           69.2
# 3           69.0
# 4           69.0
# 5           73.5
# ..           ...
# 930         64.0
# 931         62.0
# 932         61.0
# 933         66.5
# 934         57.0
#
# [934 rows x 8 columns]

# %% [markdown]
# Part a. Explore the relationship between the target variable, childHeight, and the parents heights. Do not split by gender.

# %% [markdown]
# Part b. Explore the relationship again, this time splitting the data set by gender. In other words, repeat part a, but separately for males and females.

# %%
heights_female = heights[heights.gender == "female"]
heights_female
# Out:
#     family  father  mother  midparentHeight  children  childNum  gender  \
# 2      001    78.5    67.0            75.43         4         2  female
# 3      001    78.5    67.0            75.43         4         3  female
# 4      001    78.5    67.0            75.43         4         4  female
# 7      002    75.5    66.5            73.66         4         3  female
# 8      002    75.5    66.5            73.66         4         4  female
# ..     ...     ...     ...              ...       ...       ...     ...
# 928    202    63.0    63.5            65.79         2         1  female
# 929    202    63.0    63.5            65.79         2         2  female
# 931    203    62.0    66.0            66.64         3         2  female
# 932    203    62.0    66.0            66.64         3         3  female
# 934    204    62.5    63.0            65.27         2         2  female
#
#      childHeight
# 2           69.2
# 3           69.0
# 4           69.0
# 7           65.5
# 8           65.5
# ..           ...
# 928         68.5
# 929         63.5
# 931         62.0
# 932         61.0
# 934         57.0
#
# [453 rows x 8 columns]

# %% [markdown]
# Part c. Why is separating by gender important for understanding the relationship between child's and parent's heights?

# %% [markdown]
# **Problem 2**: Continuing with Galton's height data, fit a linear regression model using midparentHeight and gender as variables.

# %% [markdown]
# Part a. Write the code to fit the model.

# %% [markdown]
# Part b. To include gender as a variable in the model, you needed to create a dummy variable. What is the base level for the variable you created.

# %% [markdown]
# Part c. Interpret both coefficients in the model you created in the context of the problem.

# %% [markdown]
# **Problem 3**: Insurance companies will use individual characteristics to predict how much an individual will cost in order to reserve enough money on hand to cover expenses. The data set we will use is from Kaggle. You can find it at: https://www.kaggle.com/datasets/mirichoi0218/insurance
#
# The full data set you get from kaggle you can get into Python using
#
# insurance_all = pd.read_csv("https://richardson.byu.edu/220/insurance_all.csv")
#
# Use this dataset to answer the remainder of the questions on the homework.

# %% [markdown]
# Part a. For each variable in the data set, list if it is continuous or categorical. If categorical specify if it is binary or not and list each value it can have.

# %% [markdown]
# Part b. Do an exploratory analysis of the data. charges is the target variable and the rest are predictors. Use figures to explore the relationship between the predictor variables in the data and charges.

# %% [markdown]
# **Problem 4** Fit a linear regression model using all the variables in the data set to predict charges.

# %% [markdown]
# Part a. Write the code that fits the model

# %% [markdown]
# Part b. For each categorical variable in the original data set, report what variables have been created to represent it in the data we use in the regression model. Report what the base level is for each categorical variable.

# %% [markdown]
# **Problem 5** Interpret coefficients

# %% [markdown]
# Part a. Explain how the effect of age is interpreted in the regression model.

# %% [markdown]
# Part b. Explain how the effect of smoking is interpreted in the regression model.

# %% [markdown]
# Part c. Explain how the effect of region is interpreted in the regression model.
