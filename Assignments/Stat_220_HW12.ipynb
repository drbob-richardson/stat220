# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drbob-richardson/stat220/blob/main/Assignments/Stat_220_HW11.ipynb)

# %% [markdown]
# **Problem 1**: A fish market spends a lot of time and money weighing each fish that comes in every day. They do not have as many scales as people and they want to find a better way. Rulers are cheaper than scales and so they want to just measure the fish lengths and widths and use that to predict weight. The data set they can use to do this can be loaded into Python using
#
# fish = pd.read_csv("https://richardson.byu.edu/220/fish.csv")
#
# The variable weight is the target variable and the rest are predictors.

# %% [markdown]
# Part a. Build a linear regression model for predicting fish weights from the other variables. Use no higher order terms but reduce the model to a significant set of predictors.

# %% [markdown]
# Part b. Use the first record in the data set. Use your model from the previous problem and predict fish weight. How close is it to the actual weight?

# %% [markdown]
# Part c. What is the confidence interval for the mean of the prediction?

# %% [markdown]
# Part d. What is the prediction interval?

# %% [markdown]
# **Problem 2** Repeat these steps using a Bayesian linear model.

# %% [markdown]
# Part a. Build a Bayesian linear regression model for predicting fish weights from the other variables. Start with the full model. Remove predictors that are not significant according to the Bayesian model output.

# %% [markdown]
# Part b. Use the first record in the data set. Use your Bayesian model from the previous problem and predict fish weight. How close is it to the actual weight?

# %% [markdown]
# Part c. Using the Bayesian model, what is the confidence interval for the mean of the prediction?

# %% [markdown]
# Part d.  Using the Bayesian model, what is the prediction interval?

# %% [markdown]
# **Problem 3** Explore using higher order terms in a Bayesian model.

# %% [markdown]
# Part a. First use a non-Bayesian model. Explore using higher order terms, but propose a final model that includes one polynomial term and one interaction. You do not have to an exhaustive search, just find a couple higher order terms that improve the model.

# %% [markdown]
# Part b. Fit a Bayesian model using the same predictors as the previous part, including the higher order terms.

# %% [markdown]
# **Problem 4** Banks use classification models to determine how risky a loan will be. They will use data on previous loans, examining characteristics about the loan type and individual and examine if they have defaulted. One such data set can be found at https://richardson.byu.edu/220/credit_risk.csv.
#
# The variable **loan_status** is 1 if the loan defaulted and 0 if it did not. The rest of the variables can be used to predict default.

# %% [markdown]
# Fit a logistic Bayesian regression model for the data. Standardize the continuous predictors and use a N(0,1) prior for each of the coefficients. Don't worry about any higher order terms.

# %% [markdown]
# **Problem 5** Use the first observation in the data set. Plot the predicted probability that the individual will default using the Bayesian model.
