# %% [markdown]
# **Problem 1**: Let X be a normal random variable with mean 8 and standard deviation 4. Find the following probabilities:

# %% [markdown]
# A. $Pr( X > 10)$

# %% [markdown]
# B. Pr(X > 10 and X < 12)

# %% [markdown]
# C. Pr(X > 10|X < 12)

# %% [markdown]
# D. Pr(X > 10|X > 8)

# %% [markdown]
# E. Pr(X > 10 and X > 8)

# %% [markdown]
# **Problem 2**: Draw 1000 random variables from a normal distribution with a mean of 50 and a variance of 100. Create an image of a histogram of the sampled data with the theoretical distribution overlaid.

# %% [markdown]
# **Problem 3** The number of times times someone yawns in a day is collected for 11 days in a row. The collected data are [1, 2, 2, 2, 3, 3, 3, 3, 10, 15, 20].

# %% [markdown]
# Part a. Assume that the true standard deviation for the number of yawns someone has in a day is 5. Plot the likelihood function as a function of $\mu$ over the range of the data.

# %% [markdown]
# Part b. What is the maximum likelihood estimate of $\mu$ assuming $\sigma = 5$.

# %% [markdown]
# Part c. Does a normal distribution seem appropriate for this data? Explain why or why not. Is there a distribution that might be better?

# %% [markdown]
# **Problem 4**: Analyze the Carbon_West data file at the book's website.

# %% [markdown]
# Part a. Assume the data comes from a normal distribution with mean $\mu$ and standard deviation $\sigma$. Find the Maximum Likelihood estimate of $\mu$ and $\sigma$.

# %% [markdown]
# Part b. Plot a histogram of the data with the theoretical normal distribution overlaid.
