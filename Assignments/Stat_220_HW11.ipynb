# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drbob-richardson/stat220/blob/main/Assignments/Stat_220_HW12.ipynb)

# %% [markdown]
# The diabetes data set contains information about individuals along with an indicator that is 1 if they have diabetes and 0 if they do not. The target variable that conatins this information is in the outcome variable. More details on teh data including information on the predictors is found at https://www.kaggle.com/datasets/mathchi/diabetes-data-set. The data you will load is slightly different than the one online.

# %%
import pandas as pd
diabetes = pd.read_csv("https://richardson.byu.edu/220/diabetes.csv")

# %% [markdown]
# Problem 1. Split the data into a training and test set set. Fit a logistic regression model to the training set predicting outcome. Find a good set of predictors including at most 3 higher order terms.

# %% [markdown]
# Problem 2. Check the performance of the model by checking accuracy and by building a confusion matrix for predictions on the test data.

# %% [markdown]
# Problem 3. Build a classification tree for the data. Check the performance of the model using accuracy and by building a confusion matrix for predictions for both the training and validation set. Tune the model to improve these values and reduce overfitting.

# %% [markdown]
# Problem 4. Calculate and plot the feature importances for the variables in the regression tree.

# %% [markdown]
# Problem 5. Compare the logistic regression model and classification tree using the Area Under the Curve scores on the test set. Which model works best?
