# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drbob-richardson/stat220/blob/main/Assignments/Stat_220_HW11.ipynb)

# %% [markdown]
# **Problem 1**: The metro data set contains information on the volume of traffic for a subway in Minneapolis. The target variable is the last variable, traffic_volume. Use the other variables to predict the traffic volume. You can read in the data using the command:
#
# pd.read_csv("https://richardson.byu.edu/220/metro.csv")
#
# For this problem use linear regression methods to build a model.

# %% [markdown]
# Part a. Fit a standard linear regression model with no higher order terms. Remove insignificant variables. Calculate and print the MSPE on the validation set. Check for overfitting by comparing the out of sample prediction error to in-sample prediction error.

# %% [markdown]
# Part b. Use a LASSO regression on the model with all the variables (no higher order terms). Determine the optimal alpha and fit the model with the optimal alpha. Calculate and print the MSPE on the test set. Check for overfitting by comparing the out of sample prediction error to in-sample prediction error.

# %% [markdown]
# Part c. Add higher order terms into the model and perform LASSO regression. Calculate and print the MSPE on the test set. Determine the optimal alpha and fit the model with the optimal alpha. Check for overfitting by comparing the out of sample prediction error to in-sample prediction error.

# %% [markdown]
# **Problem 2** Using regression trees to fit a model to the metro data.

# %% [markdown]
# Part a. Fit a decision tree model for the data. Calculate the R^2 on the validation set using several different cost complexity pruning alpha parameters. Report the best alpha you find. Plot the model R^2 on in-sample and out-of-sample predictions for various values of this parameter to show that you found a good alpha.

# %% [markdown]
# Part b. Using the best alpha you found in problem 6, build a random forest regression model where each tree is built with that alpha. Check for overfitting by comparing the out of sample prediction error to in-sample prediction error.

# %% [markdown]
# **Problem 3**: A fish market spends a lot of time and money weighing each fish that comes in every day. They do not have as many scales as people and they want to find a better way. Rulers are cheaper than scales and so they want to just measure the fish lengths and widths and use that to predict weight. The data set they can use to do this can be loaded into Python using
#
# fish = pd.read_csv("https://richardson.byu.edu/220/fish.csv")
#
# The variable weight is the target variable and the rest are predictors.

# %% [markdown]
# Part a. Build a linear regression model for predicting fish weights from the other variables. Use no higher order terms but reduce the model to a significant set of predictors.

# %% [markdown]
# Part b. Use the first record in the data set. Use your model from the previous problem and predict fish weight. How close is it to the actual weight?

# %% [markdown]
# Part c. What is the confidence interval for the mean of the prediction?

# %% [markdown]
# Part d. What is the prediction interval?

# %% [markdown]
# **Problem 4** Repeat these steps using a Bayesian linear model.

# %% [markdown]
# Part a. Build a Bayesian linear regression model for predicting fish weights from the other variables. Start with the full model. Remove predictors that are not significant according to the Bayesian model output.

# %% [markdown]
# Part b. Use the first record in the data set. Use your Bayesian model from the previous problem and predict fish weight. How close is it to the actual weight?

# %% [markdown]
# Part c. Using the Bauyesian model, what is the confidence interval for the mean of the prediction?

# %% [markdown]
# Part d.  Using the Bayesian model, what is the prediction interval?

# %% [markdown]
# **Problem 5** Explore using higher order terms in a Bayesian model.

# %% [markdown]
# Part a. First use a non-Bayesian model. Explore using higher order terms, but propose a final model that includes one polynomial term and one interaction. You do not have to an exhaustive search, just find a couple higher order terms that improve the model.

# %% [markdown]
# Part b. Fit a Bayesian model using the same predictors as the previous part, including the higher order terms.
