# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drbob-richardson/stat220/blob/main/Lecture_Code/8_3_Higher_Order_Terms.ipynb)

# %% [markdown]
# Load in libraries

# %%
# %%capture
# %pip install pydataset
# %pip install statsmodels
from pydataset import data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Working with professor salaries again.

# %%
prof = pd.DataFrame(data("Salaries"))
prof.head(10)
# Out:
#          rank discipline  yrs.since.phd  yrs.service     sex  salary
# 1        Prof          B             19           18    Male  139750
# 2        Prof          B             20           16    Male  173200
# 3    AsstProf          B              4            3    Male   79750
# 4        Prof          B             45           39    Male  115000
# 5        Prof          B             40           41    Male  141500
# 6   AssocProf          B              6            6    Male   97000
# 7        Prof          B             30           23    Male  175000
# 8        Prof          B             45           45    Male  147765
# 9        Prof          B             21           20    Male  119250
# 10       Prof          B             18           18  Female  129000

# %% [markdown]
# For now, let's just focus on the years of service variable.

# %%
plt.scatter(prof["yrs.service"],prof.salary)
plt.xlabel("Years of Service")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# Fit a linear model with years of service as the only predictor. What is the MSE. How does the line look for the fit?

# %%
X = prof[["yrs.service"]]
y = prof.salary

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=4321)

from sklearn.linear_model import LinearRegression

reg_prep = LinearRegression()
mod_reg = reg_prep.fit(X_train,y_train)

print({"Slope":mod_reg.coef_[0]})
# Out:
# {'Slope': np.float64(732.2902283695662)}

# %% [markdown]
# How does this line look compared to the data?

# %%
Beta_0 = mod_reg.intercept_
Beta_1 = mod_reg.coef_

# Plot the relationship with the straight line
plt.scatter(X,y)
x_axis = np.arange(0,60,1)
plt.plot(x_axis,Beta_0 + Beta_1*x_axis,color = "red")
plt.show()

# %% [markdown]
# How well does this fit?

# %%
out_sample_reg = mod_reg.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score


mse_reg_out = np.sqrt(mean_squared_error(y_test,out_sample_reg))
r2_reg_out = r2_score(y_test,out_sample_reg)
print(mse_reg_out)
print(r2_reg_out)
# Out:
# 30053.355951657817
# 0.12283037034036393

# %% [markdown]
# Let's now add a variable to the data frame, years squared. This is one instance of what is called a higher order term.

# %%
X = prof[["yrs.service"]].copy()
X["years_squared"] = X["yrs.service"]**2
X["years_cubed"] = X["yrs.service"]**3

X
# Out:
#      yrs.service  years_squared  years_cubed
# 1             18            324         5832
# 2             16            256         4096
# 3              3              9           27
# 4             39           1521        59319
# 5             41           1681        68921
# ..           ...            ...          ...
# 393           30            900        27000
# 394           19            361         6859
# 395           25            625        15625
# 396           15            225         3375
# 397            4             16           64
#
# [397 rows x 3 columns]

# %%
X = prof[["yrs.service"]].copy()
X["years_squared"] = X["yrs.service"]**2
X["years_cubed"] = X["yrs.service"]**3
y = prof.salary

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=4321)

reg_prep2 = LinearRegression()
mod_reg2 = reg_prep2.fit(X_train,y_train)

print({"linear term":mod_reg2.coef_[0]})
print({"quadratic term":mod_reg2.coef_[1]})
print({"cubic term":mod_reg2.coef_[2]})
# Out:
# {'linear term': np.float64(5364.027834615877)}
# {'quadratic term': np.float64(-177.7278115323017)}
# {'cubic term': np.float64(1.7095202519996124)}

# %% [markdown]
# What does this line lool like against the data?

# %%
Beta_0 = mod_reg2.intercept_
Beta_1 = mod_reg2.coef_[0]
Beta_2 = mod_reg2.coef_[1]
Beta_3 = mod_reg2.coef_[2]

plt.scatter(prof[["yrs.service"]],y)
x_axis = np.arange(0,60,1)

plt.plot(x_axis,Beta_0 + Beta_1*x_axis + Beta_2*x_axis**2 + Beta_3*x_axis**3,color = "red")
plt.show()

# %% [markdown]
# How well does this new model fit?

# %%
out_sample_reg = mod_reg2.predict(X_test)

mse_reg_out = np.sqrt(mean_squared_error(y_test,out_sample_reg))
r2_reg_out = r2_score(y_test,out_sample_reg)
print(mse_reg_out)
print(r2_reg_out)
# Out:
# 28060.566123298984
# 0.23530105031596393

# %%
X
# Out:
#      yrs.service  years_squared  years_cubed
# 1             18            324         5832
# 2             16            256         4096
# 3              3              9           27
# 4             39           1521        59319
# 5             41           1681        68921
# ..           ...            ...          ...
# 393           30            900        27000
# 394           19            361         6859
# 395           25            625        15625
# 396           15            225         3375
# 397            4             16           64
#
# [397 rows x 3 columns]

# %% [markdown]
# Let's look at the discipline variable along with years of service.

# %%
plt.scatter(prof[["yrs.service"]],y,c = prof.discipline.astype("category").cat.codes)

# %%
X = pd.get_dummies(prof[["yrs.service","discipline"]],drop_first = True)
y = prof.salary

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=4321)

reg_prep3 = LinearRegression()
mod_reg3 = reg_prep3.fit(X_train,y_train)

# %% [markdown]
# Vizualize this in 2 dimensions.

# %%
Beta_0 = mod_reg3.intercept_
Beta_1 = mod_reg3.coef_[0]
Beta_2 = mod_reg3.coef_[1]

plt.scatter(prof[["yrs.service"]],y)
x_axis = np.arange(0,60,1)

plt.plot(x_axis,Beta_0 + Beta_1*x_axis,color = "red")
plt.plot(x_axis,Beta_0 + Beta_1*x_axis + Beta_2,color = "green")
plt.show()

# %%
X = pd.get_dummies(prof[["yrs.service","discipline"]],drop_first = True)
X
# Out:
#      yrs.service  discipline_B
# 1             18          True
# 2             16          True
# 3              3          True
# 4             39          True
# 5             41          True
# ..           ...           ...
# 393           30         False
# 394           19         False
# 395           25         False
# 396           15         False
# 397            4         False
#
# [397 rows x 2 columns]

# %% [markdown]
# Let's add an interaction between discipline and years of service.

# %%
X = pd.get_dummies(prof[["yrs.service","discipline"]],drop_first = True)
y = prof.salary
X["yrs_discipline"] = X["yrs.service"]*X["discipline_B"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)


reg_prep4 = LinearRegression()
mod_reg4 = reg_prep2.fit(X_train,y_train)

# %%
X
# Out:
#      yrs.service  discipline_B  yrs_discipline
# 1             18          True              18
# 2             16          True              16
# 3              3          True               3
# 4             39          True              39
# 5             41          True              41
# ..           ...           ...             ...
# 393           30         False               0
# 394           19         False               0
# 395           25         False               0
# 396           15         False               0
# 397            4         False               0
#
# [397 rows x 3 columns]

# %%
Beta_0 = mod_reg4.intercept_
Beta_1 = mod_reg4.coef_[0]
Beta_2 = mod_reg4.coef_[1]
Beta_3 = mod_reg4.coef_[2]

plt.scatter(prof[["yrs.service"]],y)
x_axis = np.arange(0,60,1)

plt.plot(x_axis,Beta_0 + Beta_1*x_axis,color = "red")
plt.plot(x_axis,Beta_0 + Beta_2 + (Beta_1+Beta_3)*x_axis,color = "green")
plt.show()

# %%
X = pd.get_dummies(prof[["yrs.service","discipline","sex","rank"]],drop_first = True)
y = prof.salary
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)
reg_prep = LinearRegression()
mod_reg = reg_prep.fit(X_train,y_train)

out_sample_reg = mod_reg.predict(X_test)

mse_reg_out = np.sqrt(mean_squared_error(y_test,out_sample_reg))
r2_reg_out = r2_score(y_test,out_sample_reg)
print(mse_reg_out)
print(r2_reg_out)
# Out:
# 23623.950363889122
# 0.4529907611769244

# %%
X
# Out:
#      yrs.service  discipline_B  sex_Male  rank_AsstProf  rank_Prof
# 1             18          True      True          False       True
# 2             16          True      True          False       True
# 3              3          True      True           True      False
# 4             39          True      True          False       True
# 5             41          True      True          False       True
# ..           ...           ...       ...            ...        ...
# 393           30         False      True          False       True
# 394           19         False      True          False       True
# 395           25         False      True          False       True
# 396           15         False      True          False       True
# 397            4         False      True           True      False
#
# [397 rows x 5 columns]

# %%
X = pd.get_dummies(prof[["yrs.service","discipline","rank","sex"]],drop_first = True)
X["yearsquared"] = X["yrs.service"]**2
X["years_cubed"] = X["yrs.service"]**3
X["yrs_discipline"] = X["yrs.service"]*X["discipline_B"]
X["yrs_sq_disc"] = X["yearsquared"]*X["discipline_B"]
X["yrs_cbd_disc"] = X["years_cubed"]*X["discipline_B"]
y = prof.salary
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)
reg_prep = LinearRegression()
mod_reg = reg_prep.fit(X_train,y_train)

out_sample_reg = mod_reg.predict(X_test)

mse_reg_out = np.sqrt(mean_squared_error(y_test,out_sample_reg))
r2_reg_out = r2_score(y_test,out_sample_reg)
print(mse_reg_out)
print(r2_reg_out)
# Out:
# 22581.86389636016
# 0.5001851104995869

# %% [markdown]
# Let's look at the p-values we can get. This also introduces the other way to do statsmodels. One downside of using scikit-style matrices in statsmodels is you have too add a constant manually.

# %%
import statsmodels.api as sm

# Convert any Boolean columns to integers in both training and test data
X_train = X_train.astype(int)
X_test = X_test.astype(int)

# Adding a constant to the model (intercept)
X_train_sm = sm.add_constant(X_train)
X_test_sm = sm.add_constant(X_test)

# Fitting the OLS model
model = sm.OLS(y_train, X_train_sm).fit()

# Summary of the model
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 salary   R-squared:                       0.447
# Model:                            OLS   Adj. R-squared:                  0.426
# Method:                 Least Squares   F-statistic:                     21.49
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           3.63e-29
# Time:                        10:53:06   Log-Likelihood:                -3161.8
# No. Observations:                 277   AIC:                             6346.
# Df Residuals:                     266   BIC:                             6386.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           8.434e+04   9043.184      9.326      0.000    6.65e+04    1.02e+05
# yrs.service     -551.3760   1397.074     -0.395      0.693   -3302.105    2199.354
# discipline_B     647.6651   8420.480      0.077      0.939   -1.59e+04    1.72e+04
# rank_AsstProf  -1.126e+04   6480.325     -1.738      0.083    -2.4e+04    1499.215
# rank_Prof       3.436e+04   4296.973      7.996      0.000    2.59e+04    4.28e+04
# sex_Male        6368.5344   4530.701      1.406      0.161   -2552.064    1.53e+04
# yearsquared       39.4896     64.631      0.611      0.542     -87.764     166.743
# years_cubed       -0.7972      0.858     -0.929      0.354      -2.487       0.892
# yrs_discipline  2486.1433   1756.604      1.415      0.158    -972.473    5944.760
# yrs_sq_disc     -143.2070     92.458     -1.549      0.123    -325.249      38.835
# yrs_cbd_disc       2.2032      1.343      1.641      0.102      -0.440       4.847
# ==============================================================================
# Omnibus:                       39.642   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.210
# Skew:                           0.818   Prob(JB):                     4.19e-15
# Kurtosis:                       4.749   Cond. No.                     2.48e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.48e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_all = X.copy()

# %%
X = X.drop(columns = ["sex_Male"])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# Adding a constant to the model (intercept)
X_train_sm = sm.add_constant(X_train.astype(int))
X_test_sm = sm.add_constant(X_test.astype(int))

# Fitting the OLS model
model = sm.OLS(y_train, X_train_sm).fit()

# Summary of the model
print(model.summary())

# Predicting on the test set
y_pred = model.predict(X_test_sm)

# Calculating out-of-sample R^2
out_sample_r2 = r2_score(y_test, y_pred)

# Displaying the out-of-sample R^2
print(f'Out-of-sample R^2: {out_sample_r2:.4f}')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 salary   R-squared:                       0.443
# Model:                            OLS   Adj. R-squared:                  0.424
# Method:                 Least Squares   F-statistic:                     23.57
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           1.87e-29
# Time:                        10:53:12   Log-Likelihood:                -3162.9
# No. Observations:                 277   AIC:                             6346.
# Df Residuals:                     267   BIC:                             6382.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            8.94e+04   8309.962     10.758      0.000     7.3e+04    1.06e+05
# yrs.service     -455.1498   1397.943     -0.326      0.745   -3207.544    2297.244
# discipline_B    2559.1970   8325.115      0.307      0.759   -1.38e+04     1.9e+04
# rank_AsstProf  -1.195e+04   6473.725     -1.845      0.066   -2.47e+04     800.090
# rank_Prof        3.47e+04   4297.960      8.073      0.000    2.62e+04    4.32e+04
# yearsquared       35.0209     64.671      0.542      0.589     -92.308     162.350
# years_cubed       -0.7349      0.859     -0.856      0.393      -2.425       0.955
# yrs_discipline  2087.3767   1736.709      1.202      0.230   -1332.011    5506.764
# yrs_sq_disc     -125.4238     91.755     -1.367      0.173    -306.080      55.232
# yrs_cbd_disc       1.9855      1.336      1.486      0.138      -0.645       4.616
# ==============================================================================
# Omnibus:                       40.402   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.711
# Skew:                           0.831   Prob(JB):                     1.98e-15
# Kurtosis:                       4.763   Cond. No.                     2.41e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.41e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Out-of-sample R^2: 0.5004
