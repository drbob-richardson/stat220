# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drbob-richardson/stat220/blob/main/Lecture_Code/stat220_midtermtakehome_f2024.ipynb)

# %% [markdown]
# # Stat 220 Midterm Exam Fall 2024
#
# Please disable AI helpers in your environment. If working in Google Colab you can do this by going to tools, then settings, then AI assistance and clicking "Disable generative AI assistance". Note that I checked how it did on this exam and it did indeed get some things wrong, and even things that didn't throw errors, so be sure to do that.
#
# Please do not use ChatGPT or any other generative AI tools to fully answer these questions. I will allow class notes, Google search, or AI assistance for things like debugging, syntax, or looking up general principles. For example, you can Google, how do I fit a regression tree, but do not copy and paste the full problem 6.

# %% [markdown]
# #  **Part 1**

# %% [markdown]
# ## House Pricing Dataset Description
# You are provided with a dataset that can be found at https://richardson.byu.edu/220/housing_data.csv that contains information about housing prices and several features that might influence these prices. The variables in the dataset are:
# - **house_price**: The price of the house in dollars (continuous target variable).
# - **square_footage**: The size of the house in square feet (continuous predictor).
# - **num_bedrooms**: The number of bedrooms in the house (continuous predictor, but it can be treated as categorical).
# - **has_garage**: A binary variable indicating if the house has a garage (1 = Yes, 0 = No).
# - **neighborhood**: The neighborhood where the house is located (categorical variable with four levels: Downtown, Suburb, Countryside, Beachside).
# Your tasks are outlined below.

# %% [markdown]
# ## Question 1: Plotting House Price Against Neighborhood
# Create a plot that shows how the house prices vary across different neighborhoods. Describe any patterns you observe in the plot.
#
# ### Instructions:
# - Use a plot to visualize the distribution of house prices by neighborhood.

# %% [markdown]
# ## Question 2: Treating Number of Bedrooms as Continuous vs Categorical
# The variable `num_bedrooms` can be treated as either a continuous or a categorical variable. Create two plots:
# 1. One where you treat `num_bedrooms` as a continuous variable.
# 2. Another where you treat it as a categorical variable.
# Discuss which approach makes more sense and why, based on the visualizations.

# %% [markdown]
# ## Question 3: Fitting a Linear Regression Model
# Fit a linear regression model where `house_price` is the target variable, and the predictors are:
# - **square_footage**
# - **num_bedrooms** (treated as a continuous variable)
# - **has_garage**
# - **neighborhood**

# %% [markdown]
# ## Question 4: Interpreting the Coefficients
# Interpret the coefficients from your linear regression model.

# %% [markdown]
# ## Question 5: Fitting a Regression Tree
# Fit a regression tree using `house_price` as the target and the same predictors you used in the linear regression model (i.e., `square_footage`, `num_bedrooms`, `has_garage`, and `neighborhood`).
#  Plot the resulting tree.

# %% [markdown]
# ## Question 6: Predicting with New Data
# A new house has the following features:
# - **square_footage**: 2200
# - **num_bedrooms**: 4
# - **has_garage**: 1 (Yes)
# - **neighborhood**: "Suburb"
#
# Predict the price of this house using both the linear regression model and the regression tree model you fit earlier. Compare the predictions from both models.

# %% [markdown]
# ## Question 7: Explaining the Effect of Neighborhood in the Models
# Your supervisor is not technically trained and is wondering specifically about how nighborhood is used to predict house price. Explain how the neighborhood affects the house price prediction in *both the linear regression model and the regression tree model*. Consider:
# - How neighborhood is treated in each model.
# - Whether it seems like the two models agree with each other as far as the effect of neighborhood

# %% [markdown]
# #  **Part 2**

# %% [markdown]
# You are provided with data from the last 10 days, showing the number of products sold and the number of complaints received each day. The data is as follows:
#
# | Day | X (Products Sold) | Y (Complaints) |
# |-----|-------------------|----------------|
# | 1   | 75                | 4              |
# | 2   | 60                | 6              |
# | 3   | 90                | 7              |
# | 4   | 20                | 1              |
# | 5   | 100               | 7              |
# | 6   | 50                | 3              |
# | 7   | 85                | 6              |
# | 8   | 30                | 2              |
# | 9   | 60                | 4              |
# | 10  | 40                | 1              |

# %% [markdown]
# ## Question 8: Mutually Exclusive
#
# Let Event A represent 'the number of products sold being more than 50' and Event B represent 'the number of complaints being more than 5'. Based on the last 10 days of data, determine if events A and B are mutually exclusive and justify your answer.

# %% [markdown]
# ## Question 9: Independence
# Continuing from problem 8, determine if there is evidence for or against Events A and B being independent and justify your answer.

# %% [markdown]
# ## Question 10: Conditional probability
#
# Using the data above, estimate the conditional probability of event B given event A occured, $Pr(B|A)$.

# %% [markdown]
# ## Question 11: Estimating Expected Complaints with Binomial Model
# Assume that the number of complaints (`Y`) follows a binomial distribution, with `n` equal to the number of products sold (`X`) on a given day, and `p = 0.1`. Calculate the expected number of complaints for each of the 10 days using this model. How do they compare to the actual complaints?

# %% [markdown]
# ## Question 12: MLE for Number of Products Sold (Larger Dataset)
# You are provided with a larger dataset containing data for a longer period. You can download the dataset from the following link: [Products Sold Dataset](https://richardson.byu.edu/220/product_sales_complaint_data.csv).
#
# Using this data set, assume that the number of products sold follows a normal distribution with parameters $\mu$ and $\sigma$. Determine the maximum likelihood estimates of teh unknown parameters.

# %% [markdown]
# ## Question 13: Normal probability values
#
# Use the MLE estimates from the last problem. Determine the probability that there is a day with higher than 80 products sold *or* less than 20 products sold.

# %% [markdown]
# ## Question 14: Bayesian Regression Model for Complaints
# Fit a Bayesian regression model to predict the number of complaints (`Y`) based on the number of products sold (`X`) using the larger data set. Use the following priors for the regression coefficients:
# - Slope ($\beta_1$): Normally distributed with mean 0 and variance 10, i.e., `N(0, 10)`.
# - Intercept ($\beta_0$): Normally distributed with mean 0 and variance 10, i.e., `N(0, 10)`.

# %% [markdown]
# ## Question 15 Bayes estimates
#
# What is Bayes estimate for $\beta_1$.

# %% [markdown]
# ## Question 16: Probability of Regression Coefficient
#
# What is the probability that $\beta_1$ is larger than 0.1?
