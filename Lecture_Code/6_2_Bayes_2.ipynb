# %%
# !pip install bambi
# Out:
# Collecting bambi
#   Downloading bambi-0.12.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.4/79.4 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: arviz>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from bambi) (0.15.1)
# Collecting formulae>=0.5.0 (from bambi)
#   Downloading formulae-0.5.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from bambi) (0.20.1)
# Requirement already satisfied: numpy>1.22 in /usr/local/lib/python3.10/dist-packages (from bambi) (1.23.5)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bambi) (1.5.3)
# Requirement already satisfied: pymc>=5.5.0 in /usr/local/lib/python3.10/dist-packages (from bambi) (5.7.2)
# Requirement already satisfied: pytensor>=2.12.3 in /usr/local/lib/python3.10/dist-packages (from bambi) (2.14.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from bambi) (1.11.3)
# Requirement already satisfied: setuptools>=60.0.0 in /usr/local/lib/python3.10/dist-packages (from arviz>=0.12.0->bambi) (67.7.2)
# Requirement already satisfied: matplotlib>=3.2 in /usr/local/lib/python3.10/dist-packages (from arviz>=0.12.0->bambi) (3.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from arviz>=0.12.0->bambi) (23.2)
# Requirement already satisfied: xarray>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from arviz>=0.12.0->bambi) (2023.7.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from arviz>=0.12.0->bambi) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from arviz>=0.12.0->bambi) (4.5.0)
# Requirement already satisfied: xarray-einstats>=0.3 in /usr/local/lib/python3.10/dist-packages (from arviz>=0.12.0->bambi) (0.6.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->bambi) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->bambi) (2023.3.post1)
# Requirement already satisfied: cachetools>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from pymc>=5.5.0->bambi) (5.3.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from pymc>=5.5.0->bambi) (2.2.1)
# Requirement already satisfied: fastprogress>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from pymc>=5.5.0->bambi) (1.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from pytensor>=2.12.3->bambi) (3.12.4)
# Requirement already satisfied: etuples in /usr/local/lib/python3.10/dist-packages (from pytensor>=2.12.3->bambi) (0.3.9)
# Requirement already satisfied: logical-unification in /usr/local/lib/python3.10/dist-packages (from pytensor>=2.12.3->bambi) (0.4.6)
# Requirement already satisfied: miniKanren in /usr/local/lib/python3.10/dist-packages (from pytensor>=2.12.3->bambi) (1.0.3)
# Requirement already satisfied: cons in /usr/local/lib/python3.10/dist-packages (from pytensor>=2.12.3->bambi) (0.4.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from h5netcdf>=1.0.2->arviz>=0.12.0->bambi) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->arviz>=0.12.0->bambi) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->arviz>=0.12.0->bambi) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->arviz>=0.12.0->bambi) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->arviz>=0.12.0->bambi) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->arviz>=0.12.0->bambi) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2->arviz>=0.12.0->bambi) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->bambi) (1.16.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from logical-unification->pytensor>=2.12.3->bambi) (0.12.0)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.10/dist-packages (from logical-unification->pytensor>=2.12.3->bambi) (1.0.0)
# Installing collected packages: formulae, bambi
# Successfully installed bambi-0.12.0 formulae-0.5.1

# %% [markdown]
# Import scottish hills race data. The Distance is how far the race is in miles. The climb is the difference in height from the end to the beginning. The Time is how long it took to finish.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


hills = pd.read_table("http://www.statsci.org/data/general/hills.txt")
hills
# Out:
#                Race  Distance  Climb     Time
# 0       Greenmantle       2.5    650   16.083
# 1          Carnethy       6.0   2500   48.350
# 2       CraigDunain       6.0    900   33.650
# 3            BenRha       7.5    800   45.600
# 4         BenLomond       8.0   3070   62.267
# 5          Goatfell       8.0   2866   73.217
# 6        BensofJura      16.0   7500  204.617
# 7       Cairnpapple       6.0    800   36.367
# 8            Scolty       5.0    800   29.750
# 9          Traprain       6.0    650   39.750
# 10       LairigGhru      28.0   2100  192.667
# 11           Dollar       5.0   2000   43.050
# 12          Lomonds       9.5   2200   65.000
# 13       CairnTable       6.0    500   44.133
# 14        EildonTwo       4.5   1500   26.933
# 15        Cairngorm      10.0   3000   72.250
# 16       SevenHills      14.0   2200   98.417
# 17        KnockHill       3.0    350   78.650
# 18        BlackHill       4.5   1000   17.417
# 19        CreagBeag       5.5    600   32.567
# 20      KildconHill       3.0    300   15.950
# 21  MeallAnt-Suidhe       3.5   1500   27.900
# 22     HalfBenNevis       6.0   2200   47.633
# 23          CowHill       2.0    900   17.933
# 24      NBerwickLaw       3.0    600   18.683
# 25        CreagDubh       4.0   2000   26.217
# 26        Burnswark       6.0    800   34.433
# 27         LargoLaw       5.0    950   28.567
# 28          Criffel       6.5   1750   50.500
# 29           Acmony       5.0    500   20.950
# 30         BenNevis      10.0   4400   85.583
# 31      Knockfarrel       6.0    600   32.383
# 32     TwoBreweries      18.0   5200  170.250
# 33        Cockleroi       4.5    850   28.100
# 34      MoffatChase      20.0   5000  159.833

# %%
plt.scatter(hills.Climb,hills.Time)

# %% [markdown]
# Build a Bayesian linear model using distance to predict time. Running up hill, how much longer would you expect to take for one additional mile?

# %%
import bambi as bmb
import arviz as az

# Initialize a Bayesian linear model
model = bmb.Model('Time ~ Distance',hills)

priors = {
"Intercept": bmb.Prior("Normal", mu=0, sigma=100),
"Distance": bmb.Prior("Normal", mu=7, sigma=5)
}
model.set_priors(priors=priors)
# Fit the model, do 4 different series of draws of length 1000
results = model.fit(draws=1000, chains=4)

# Plot the draws as a trace function and as a histogram of the draws
az.plot_trace(results)
plt.show()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:02&lt;00:00 Sampling chain 0, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:03&lt;00:00 Sampling chain 1, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:02&lt;00:00 Sampling chain 2, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:02&lt;00:00 Sampling chain 3, 0 divergences]
#     </div>

# %%
az.summary(results)
# Out:
#               mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# Intercept   -4.937  5.899 -15.860    6.122      0.076    0.072    6129.0
# Distance     8.331  0.639   7.108    9.470      0.009    0.006    5521.0
# Time_sigma  20.666  2.672  16.153   25.933      0.041    0.030    4407.0
#
#             ess_tail  r_hat
# Intercept     3323.0    1.0
# Distance      3286.0    1.0
# Time_sigma    3086.0    1.0

# %%
posterior = results.posterior.stack({"draws":["chain","draw"]})
distance_post = posterior["Distance"].values
distance_post
# Out:
# array([9.03974752, 8.05614911, 8.02726651, ..., 8.05294347, 8.39418034,
#        8.07580388])

# %%
intercept_post = posterior["Intercept"].values
intercept_post
# Out:
# array([-7.04425556, -5.84620988, -1.73333666, ...,  0.61531435,
#        -9.15462427, -1.74109351])

# %% [markdown]
# What is the probability the estimate for Beta_1 is more than 9? Meaning the average time added per mile is more than 9 minutes?

# %%
np.sum(distance_post > 9 )/len(distance_post)
# Out:
# 0.147

# %% [markdown]
# Multiple variables

# %%
# Initialize a Bayesian linear model
model = bmb.Model('Time ~ Distance + Climb',hills)

priors = {
"Intercept": bmb.Prior("Normal", mu=0, sigma=100),
"Distance": bmb.Prior("Normal", mu=7, sigma=5),
"Climb": bmb.Prior("Normal", mu=.1, sigma=5)
}
model.set_priors(priors=priors)
# Fit the model, do 4 different series of draws of length 1000
results = model.fit(draws=1000, chains=4)

# Plot the draws as a trace function and as a histogram of the draws
az.plot_trace(results)
plt.show()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:06&lt;00:00 Sampling chain 0, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:07&lt;00:00 Sampling chain 1, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:05&lt;00:00 Sampling chain 2, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:07&lt;00:00 Sampling chain 3, 0 divergences]
#     </div>

# %%
az.summary(results)
# Out:
#               mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# Intercept   -9.041  4.603 -17.990   -0.461      0.064    0.047    5193.0
# Distance     6.223  0.636   5.067    7.396      0.012    0.009    2876.0
# Climb        0.011  0.002   0.007    0.015      0.000    0.000    2557.0
# Time_sigma  15.288  2.066  11.715   19.180      0.038    0.027    3026.0
#
#             ess_tail  r_hat
# Intercept     3451.0    1.0
# Distance      2409.0    1.0
# Climb         2890.0    1.0
# Time_sigma    2689.0    1.0

# %%
posterior = results.posterior.stack({"draws":["chain","draw"]})
distance_post = posterior["Distance"].values
distance_post
# Out:
# array([4.83781917, 5.53281887, 6.60614679, ..., 7.28102354, 6.43901073,
#        6.77672085])

# %%
climb_post = posterior["Climb"].values
climb_post
# Out:
# array([0.01628196, 0.01377522, 0.00795172, ..., 0.00859324, 0.00729821,
#        0.00781501])
